# %% [markdown]
# # Football Player Data Cleaning and Audit
# **Student:** Wun-nam Kyirifo Haruna
# **Role:** Data collection, cleaning, and K-Means clustering

# %% [markdown]
# ## Objective
# Create a reproducible cleaning pipeline, resolve multiple positions, separate goalkeepers from outfield players, apply a 900-minute baseline eligibility threshold, and prepare the data for position-aware K-Means clustering.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

DATA = Path('players_data-2025_2026.csv')
df = pd.read_csv(DATA)
df.shape
# Out:
# (2839, 102)

# %%
df.head()
# Out:
#    Rk               Player   Nation    Pos              Squad  \
# 0   1     Brenden Aaronson   us USA  MF,FW       Leeds United
# 1   2         Jerome Abbey  eng ENG     MF             Wolves
# 2   3          Zach Abbott  eng ENG     DF  Nottingham Forest
# 3   4  Jones El-Abdellaoui   ma MAR  MF,FW         Celta Vigo
# 4   5        Himad Abdelli   dz ALG     MF          Marseille
#
#                  Comp   Age    Born  MP  Starts  ...  CrdY_stats_misc  \
# 0  eng Premier League  24.0  2000.0  37      30  ...                3
# 1  eng Premier League  15.0  2009.0   1       0  ...                0
# 2  eng Premier League  19.0  2006.0   3       2  ...                0
# 3          es La Liga  19.0  2006.0  22       4  ...                0
# 4          fr Ligue 1  25.0  1999.0   8       1  ...                1
#
#    CrdR_stats_misc  2CrdY  Fls  Fld  Off  Crs  Int  TklW  OG
# 0                0      0   20   51    5   37   17    27   0
# ...

# %%
audit = pd.DataFrame({
    'dtype': df.dtypes.astype(str),
    'missing_count': df.isna().sum(),
    'missing_pct': (df.isna().mean() * 100).round(2),
    'unique_values': df.nunique(dropna=True)
}).sort_values('missing_pct', ascending=False)
audit.head(20)
# Out:
#                        dtype  missing_count  missing_pct  unique_values
# CS%                  float64           2651        93.38             87
# Save%                float64           2649        93.31            116
# SoTA                 float64           2645        93.17            114
# Comp_stats_keeper        str           2645        93.17              5
# Born_stats_keeper    float64           2645        93.17             23
# MP_stats_keeper      float64           2645        93.17             38
# Starts_stats_keeper  float64           2645        93.17             38
# Min_stats_keeper     float64           2645        93.17             96
# 90s_stats_keeper     float64           2645        93.17             82
# GA                   float64           2645        93.17             60
# GA90                 float64           2645        93.17            100
# Saves                float64           2645        93.17             93
# ...

# %% [markdown]
# ## Cleaning design
# The first listed position is treated as the primary position. The second, where present, is retained rather than discarded. Goalkeepers are modelled separately because their performance variables are not comparable with outfield-player variables.

# %%
# Run the prepared cleaning script or reproduce the same logic here.
cleaned = pd.read_csv('football_player_project/players_cleaned_master.csv')
cleaned[['Player','Pos','Primary_Position','Secondary_Position','Position_Group','Min','Eligible_900']].head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Run the prepared cleaning script or reproduce the same logic here.
# ----> 2 cleaned = pd.read_csv('football_player_project/players_cleaned_master.csv')
#       3 cleaned[['Player','Pos','Primary_Position','Secondary_Position','Position_Group','Min','Eligible_900']].head(10)
#
# ...

# %%
cleaned['Position_Group'].value_counts()

# %%
cleaned.groupby('Position_Group')['Min'].describe().round(1)

# %% [markdown]
# ## Modelling readiness decision
# The baseline clustering sample uses players with at least 900 minutes. This threshold reduces small-sample distortion while retaining a substantial dataset. The next notebook will select role-relevant features, standardise them within position groups, test candidate values of K, and interpret cluster centroids.
